# %% [markdown]
# <a href="https://colab.research.google.com/github/aeldemerdash/Essential-Machine-Learning-and-AI-with-Python-and-Jupyter-Notebook/blob/master/Lesson%201%3A%20Introducing%20Data%20Science%20Coding%20with%20Python%20Fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-
"""
Created on Tue Jan  8 07:42:04 2019

@author: aeldemerdash
"""

steps =(1+1)-1
print(f"Two steps forward: one step Back = {steps}")

body_fat_percentage =0.10
weight =200
fat_total = body_fat_percentage * weight
print(f"I weight 200lbs, and {fat_total} lbs of that fat")



from decimal import (Decimal, setcontext)
setcontext = 10
Decimal(1) /Decimal(3)


import math
math.pow(2,3)
2**3 #the same 


number =10
num_type = type(number).__name__
print(f"{number} is type {num_type}")

number =float(10)
num_type = type(number).__name__
print(f"{number} is type {num_type}")

to_many_decimals= 1.923453276457624
# %timeit round(to_many_decimals,2)

import numpy as np
# %timeit np.round(to_many_decimals,2)

import pandas as pd
df = pd.DataFrame([to_many_decimals],columns=['A'],index=['First'])
# %timeit df.round(2)


submition = {"qq_item" : "qq","cc_item":"cc","dd_item":"dd"}
type(submition)

submition_dic = dict(qq="qq",bb="bb")
type(submition_dic)

for key,value in submition.items() :
    if "qq_item" in key:
        print(f"{key}  {value}")

type(submition.items())
type(submition.keys())
type(submition.values()) 

# %timeit if "qq" in submition : pass


list_of_data = ["6","5","4","3","2","1"]
type(list_of_data)

for listItem in list_of_data :
        print(listItem)
        

v_x_list = list()
v_x_list.append(1)
v_x_list.append("x")
v_x_list.append('x')
type(v_x_list)

for listItem in v_x_list:
    print(listItem)

type(v_x_list[0])  
type(v_x_list[1])
type(v_x_list[2])


guards ="full,half,open"
type(guards)

guard_list = [f"{guard}-guard" for guard in guards.split(",")]

type(guard_list[:1])
type(guard_list[-1:])
guard_list[0:3]

list_of_list = [[1,2,3,],[4,5,6],[7,8,9]]
x = set(zip(*list_of_list))

b1 = set(("a","b","d"))
b2 = set(("a","b","c"))
b3 = b2 - b1
# Out:
# Two steps forward: one step Back = 1
# I weight 200lbs, and 20.0 lbs of that fat
# 10 is type int
# 10.0 is type float
# The slowest run took 11.78 times longer than the fastest. This could mean that an intermediate result is being cached.
# 1000000 loops, best of 3: 465 ns per loop
# The slowest run took 14.69 times longer than the fastest. This could mean that an intermediate result is being cached.
# 100000 loops, best of 3: 7.45 µs per loop
# 1000 loops, best of 3: 972 µs per loop
# qq_item  qq
# 10000000 loops, best of 3: 42.5 ns per loop
# 6
# 5
# 4
# 3
# 2
# 1
# 1
# x
# x
